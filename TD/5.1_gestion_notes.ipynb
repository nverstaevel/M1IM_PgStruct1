# %% [markdown]
# # Gestion des notes ⭐⭐

# %% [markdown]
# ## Tâche à réaliser 🎯
#
# Le professeur Lambda vous demande de l'aide pour gérér les notes qu'il attribue à ses étudiants.
# Pour chaque étudiant, il veut conserver ses numéro d'étudiant, nom et prénom.
# Chaque année, il effectue plusieurs évaluations, ces évaluations pouvant avoir des coefficients différents.
#
# Il souhaiterai une application qui lui fournissent automatiquement :
# - la moyenne de chaque étudiant et son résultat (recalé, admis (entre 10 et 12 non compris), mention Assez Bien (entre 12 et 14 non compris), mention Bien (entre 14 et 16 non compris), mention Très Bien (supérieur à 16))
# - le nombre d'étudiants recalés pour pouvoir prévoir les rattrapages
#
# Vous devez analyser ce cas pour :
# - prévoir les structures de données nécessaires (celles ci ne seront pas saisies mais remplies en début de programme)
# - prévoir les différents traitements nécessaires (pensez au découpage en fonctions)
# - prévoir les jeux d'essais
# - programmer l'ensemble

# %% [markdown]
# ### Votre solution :

# %% [markdown]
# ## [Home](0_Index.ipynb)🏠
# ![licence.png](pics/licence.png) Licence Creative Commons Attribution - Partage dans les Mêmes Conditions 4.0 International
