# %% [markdown]
# # Calcul d'annuité ⭐

# %% [markdown]
# ### Tâche à réaliser 🎯
#
# Une annuité est une somme d'argent versée annuellement par un emprunteur pour rembourser une dette. Elle est constituée d'une partie du capital emprunté ainsi que des intérêts dûs.
# Spécifiez et implémentez un algorithme qui calcule l’annuité de remboursement d’un capital emprunté $C$ sur une durée $n$ (comprise en 3 et 20) et à un taux d’intérêt $t$ d’intérêt (compris entre 0 et 1, 0 exclus).
#
# L'annuité de remboursement est constante, annuelle et déterminée par la formule suivante:
#
# $A=C*t*(1+t)^n/((1+t)^n-1)$
#
# ### Entrées 🔠
#
# Le montant $C$ du capital emprunté, la durée $n$ de l'emprunt et le taux d'intérêt $t$, saisis par l'utilisateur.
#
# ### Sortie 🖥️
# Le montant de l'annuité de remboursement calculé grâce à la formule, et le montant total emprunté (annuité multipliée par le nombre d'années d'emprunt).
#
# ### Exemples 👀
#
# Entrées:
# > C = 1000, n= 5, t=0.1
#
# Sortie:
# > Annuité: 263.80 Montant total: 1318.99
#
# Entrée:
# > C = 241522, n= 20, t=0.2
#
# Sortie:
# > Annuité: 49598.12 Montant total: 991962.40

# %% [markdown]
# ## Votre solution :

# %% [markdown]
# ## [Home](0_Index.ipynb)🏠
# ![licence.png](pics/licence.png) Licence Creative Commons Attribution - Partage dans les Mêmes Conditions 4.0 International
