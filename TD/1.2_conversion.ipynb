# %% [markdown]
# # Convertir les $ en € et inversement ⭐

# %% [markdown]
# ### Tâche à réaliser 🎯
# Ecrire un algorithme permettant de convertir une somme dans une autre monnaie.
#
# 1 USD = 1,00660 EUR, 1 EUR = 0,99340 USD.
#
# ### Entrée 🔠
# Un montant dans une des deux monnaies, sans symbole de devise.
#
# ### Sortie 🖥️
# Le montant considéré comme EUR et converti en USD.
# Le montant considéré comme USD et converti en EUR.
#
# ### Exemples 👀
#
# Entrée: 10
#
# > Sortie: 10EUR = 9.934USD, 10USD=10.066EUR

# %% [markdown]
# ## Votre solution :

# %% [markdown]
# ## [Home](0_Index.ipynb)🏠
# ![licence.png](pics/licence.png) Licence Creative Commons Attribution - Partage dans les Mêmes Conditions 4.0 International
