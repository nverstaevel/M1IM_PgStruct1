# %% [markdown]
# # Quel est l'age du capitaine? ⭐

# %% [markdown]
# ### Tâche à réaliser 🎯
#
# Le capitaine d'un navire, son second et le premier mousse ont la spécificité d'avoir leurs âges qui forment une suite arithmétique : la différence d'âge entre le second et le mousse est la moitié de la différence d'âge entre le capitaine et le second. Par exemple, leurs âges pourraient être 15, 20 et 30.
#
# Compte tenu de l'âge du mousse, et celui du second, quel est l'âge du capitaine ?
#
# ### Entrée 🔠
#
# $M$ est l'age du mousse, et $S$ est l'age du second. On sait que $(0<=M<=50)$ et $(M<=S<=50)$.
#
# ### Sortie 🖥️
# Donnez l'age du capitaine!
#
# ### Exemples 👀
#
# Entrée: M=15, S=20
#
# > Sortie: Le Capitaine a 30 ans.

# %% [markdown]
# ## Votre solution :

# %% [markdown]
# ## [Home](0_Index.ipynb)🏠
# ![licence.png](pics/licence.png) Licence Creative Commons Attribution - Partage dans les Mêmes Conditions 4.0 International
