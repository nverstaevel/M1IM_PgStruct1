# %% [markdown]
# # ![./pics/logo_ut1.jpg](../pics/logo_ut1.jpg) Master 1 Ingénierie Métier (IM) : Programmation Structurée 1 2022/2023
#
# # Quizz 1: Variables, opérateurs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1) Quel est le résultat de ce programme ?

# %%
1 + 1/2

# %% [markdown]
# ## 2) Quel est le résultat de ce programme ?

# %%
2.0 * 3

# %% [markdown]
# ## 3) Quel est le résultat de ce programme ?

# %%
"4*5"

# %% [markdown]
# ## 4) Quel est le résultat de ce programme ?

# %%
( 6 * 3 <= 34 / 2 ) or ( 4 * 12 != 48 ) or ( 2 == 1 / 1 )

# %% [markdown]
# ## 5) Que contient la variable c?

# %%
a = 3
b = 4
c = 5
c = (a + b)*c
print(c)
# Out:
# 35

# %% [markdown]
# ## 6) Quel est le résultat de ce programme ?

# %%
ma_string = "Les feuilles l'Automne sont rouges"
ma_string = ma_string + ' et vertes'
print(ma_string)
# Out:
# Les feuilles l'Automne sont rouges et vertes

# %% [markdown]
# ## 7) Que contient la variable c à la fin du programme ?

# %%
a='cinq2'
b='cinq'
c=b<a
print(c)
# Out:
# True

# %% [markdown]
# ## 8) Que contient la variable c à la fin du programme ?

# %%
a='0'
b='Y'
c=(b+a*2+b)
c=c[1::1]
print(c)
# Out:
# 00Y

# %% [markdown]
# ## 9) Quel est le résultat de ce programme ?

# %%
a='M'
b='5'
c=6*b
print(c)
# Out:
# 555555

# %% [markdown]
# ## 10) Que contient la variable y à la fin du programme ?

# %%
y=2==1
y=3<=5
x=3!=1
w=8==4
x=724.74194
w=17,10
y=148.3
